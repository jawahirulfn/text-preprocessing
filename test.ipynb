# %%
import pandas as pd 
import numpy as np

# %%
pemilu_data = pd.read_csv('dataset/pemilu-2024.csv')

# %%
pemilu_data['news-title'].head(50)
# Out:
# 0     DPO PPLN Kuala Lumpur Serahkan Diri, Langsung ...
# 1     Pengamat Nilai Prabowo-Gibran Sebagai Kunci De...
# 2     Hasil Rekapitulasi 16 Provinsi, Prabowo-Gibran...
# 3     DPR Undang KPU Rapat Evaluasi Pemilu 2024 Sete...
# 4      Kris Dayanti Akui Gagal Lolos DPR di Pemilu 2024
# 5          KPU Tunda Rekapitulasi Suara Nasional Sulbar
# 6     Hari Pertama Puasa, Prabowo Unggah Foto Makan ...
# 7     KPU: Airin Rachmi Caleg Suara Terbanyak di Dap...
# 8     Terpilih Lagi di NTT, Caleg DPR NasDem Ratu Wu...
# 9     Raja Yordania Sapa Prabowo 'My Brother, My Fri...
# 10    DPO PPLN Kuala Lumpur Serahkan Diri, Langsung ...
# 11    Pengamat Nilai Prabowo-Gibran Sebagai Kunci De...
# 12    Hasil Rekapitulasi 16 Provinsi, Prabowo-Gibran...
# 13    DPR Undang KPU Rapat Evaluasi Pemilu 2024 Sete...
# 14     Kris Dayanti Akui Gagal Lolos DPR di Pemilu 2024
# 15         KPU Tunda Rekapitulasi Suara Nasional Sulbar
# 16    Hari Pertama Puasa, Prabowo Unggah Foto Makan ...
# 17    KPU: Airin Rachmi Caleg Suara Terbanyak di Dap...
# 18    Terpilih Lagi di NTT, Caleg DPR NasDem Ratu Wu...
# 19    Raja Yordania Sapa Prabowo 'My Brother, My Fri...
# 20    Mega Instruksikan Kader Tertawa dan Menangis B...
# 21    Arahan Megawati: Jateng Kandang Banteng, Harus...
# 22    FOTO: Konsolidasi untuk Pemilu dan Pilpres, Ka...
# 23    Gibran Hadiri Konsolidasi Pemenangan PDIP dan ...
# 24    Ganjar-Puan Hadiri Konsolidasi di Semarang, Te...
# 25    Anies Baswedan Tiba di Rumah SBY di Cikeas, Ba...
# 26    VIDEO: Budiman Sudjatmiko Dipecat, Puan: Sudah...
# 27    PKB Ajak Budiman Sudjatmiko Bergabung, Ditawar...
# 28    Demokrat: Anies dan SBY Bahas Strategi Pemenan...
# 29    NasDem Ungkap Isi Pertemuan 5 Jam Anies dan Su...
# 30    VIDEO: Momen Pertemuan SBY-Anies Bahas Strateg...
# 31    Megawati Inginkan RI Mandiri, Singgung Penelit...
# 32    Demokrat Respons Survei Elektabilitas Anies ya...
# 33    SBY Suguhi Anies Bakso Sukowati di Cikeas: Pun...
# 34    Puan Pamer Tongkat Komando Simbol Amanat Bung ...
# 35    Ganjar Puja-puji Terobosan Infrastruktur Jokow...
# 36    Ganjar ke Kader PDIP: Kita Seruduk Sekat Pengh...
# 37    Puan Sindir Kawan Jadi Lawan: Tapi Bukan Bante...
# 38    PDIP Siapkan Pasukan Gorong-gorong dan Burung ...
# 39    Megawati: Jangan Tolah-Toleh Lagi, Menangkan P...
# 40    Bakso Sukowati yang Disantap Anies, Gema Presi...
# 41    FOTO: Anies Baswedan dan Tim Delapan Temui SBY...
# 42    VIDEO: Momen Puan Angkat Tinggi Tongkat Simbol...
# 43    VIDEO: Ganjar Puji Kepemimpinan Jokowi: Kita H...
# 44    MK Izinkan Kampanye di Kampus dan Sekolah, Roc...
# 45    VIDEO: Kala Puan Getarkan Semangat Kader PDIP ...
# 46    ICW Ungkap 12 Bakal Caleg Berstatus Mantan Nap...
# 47    RK soal Elektabilitas Golkar Melorot: Lagi Tur...
# 48    Gabung NasDem, Ketum Forkabi Dukung Anies Basw...
# 49    Rektor Unhas Siap Gelar Debat dan Diskusi Tiga...
# Name: news-title, dtype: object

# %% [markdown]
# ## Case Folding

# %%
pemilu_data['news-title'] = pemilu_data['news-title'].str.lower()

print('Case Folding Result : \n')
print(pemilu_data['news-title'].head())
# Out:
# Case Folding Result :
#
# 0    dpo ppln kuala lumpur serahkan diri, langsung ...
# 1    pengamat nilai prabowo-gibran sebagai kunci de...
# 2    hasil rekapitulasi 16 provinsi, prabowo-gibran...
# 3    dpr undang kpu rapat evaluasi pemilu 2024 sete...
# 4     kris dayanti akui gagal lolos dpr di pemilu 2024
# Name: news-title, dtype: object

# %% [markdown]
# ## Tokenizing

# %%
import string
import re #regex library

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist

# Tokenizing
def remove_tweet_special(text):
    # remove tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")

pemilu_data['news-title'] = pemilu_data['news-title'].apply(remove_tweet_special)

# remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

pemilu_data['news-title'] = pemilu_data['news-title'].apply(remove_number)

#remove punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

pemilu_data['news-title'] = pemilu_data['news-title'].apply(remove_punctuation)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

pemilu_data['news-title'] = pemilu_data['news-title'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

pemilu_data['news-title'] = pemilu_data['news-title'].apply(remove_whitespace_multiple)

# remove single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

pemilu_data['news-title'] = pemilu_data['news-title'].apply(remove_singl_char)

# %%
# NLTK word rokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

pemilu_data['news-tokens'] = pemilu_data['news-title'].apply(word_tokenize_wrapper)

# %%
print('Tokenizing Result : \n') 
print(pemilu_data['news-tokens'].head())
print('\n\n\n')
# Out:
# Tokenizing Result :
#
# 0    [dpo, ppln, kuala, lumpur, serahkan, diri, lan...
# 1    [pengamat, nilai, prabowogibran, sebagai, kunc...
# 2    [hasil, rekapitulasi, provinsi, prabowogibran,...
# 3    [dpr, undang, kpu, rapat, evaluasi, pemilu, se...
# 4    [kris, dayanti, akui, gagal, lolos, dpr, di, p...
# Name: news-tokens, dtype: object

# %% [markdown]
# ## Menghitung frekuensi distribusi token

# %%
def freqDist_wrapper(text):
    return FreqDist(text)

pemilu_data['news-tokens-fdist'] = pemilu_data['news-tokens'].apply(freqDist_wrapper)

print('Frequency Tokens: \n')
print(pemilu_data['news-tokens-fdist'].head())
# Out:
# Frequency Tokens:
#
# 0    {'dpo': 1, 'ppln': 1, 'kuala': 1, 'lumpur': 1,...
# 1    {'pengamat': 1, 'nilai': 1, 'prabowogibran': 1...
# 2    {'hasil': 1, 'rekapitulasi': 1, 'provinsi': 1,...
# 3    {'dpr': 1, 'undang': 1, 'kpu': 1, 'rapat': 1, ...
# 4    {'kris': 1, 'dayanti': 1, 'akui': 1, 'gagal': ...
# Name: news-tokens-fdist, dtype: object

# %% [markdown]
# ## Filtering (Stopword Removal)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\M JAWAHIRUL
# [nltk_data]     FANANI\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# get stopword from nltk stopword
# get stopword indonesia
list_stopwords = stopwords.words('indonesian')

# manually add stopword
# append additional stopword
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah', 'dan'])

# ----------------------- add stopword from txt file ------------------------------------
# read txt stopword using pandas
# txt_stopword = pd.read_csv("stopwords.txt", names= ["stopwords"], header = None)

# convert stopword string to list & append additional stopword
# list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))

# convert list to dictionary
list_stopwords = set(list_stopwords)

# remove stopword pada list token
def stopword_removal(words):
    return[word for word in words if word not in list_stopwords]

pemilu_data['news-tokens-wsw'] = pemilu_data['news-tokens'].apply(stopword_removal)

print(pemilu_data['news-tokens'].head())
# Out:
# 0    [dpo, ppln, kuala, lumpur, serahkan, diri, lan...
# 1    [pengamat, nilai, prabowogibran, sebagai, kunc...
# 2    [hasil, rekapitulasi, provinsi, prabowogibran,...
# 3    [dpr, undang, kpu, rapat, evaluasi, pemilu, se...
# 4    [kris, dayanti, akui, gagal, lolos, dpr, di, p...
# Name: news-tokens, dtype: object

# %% [markdown]
# ## Normalization

# %%
# Membaca file normalisasi.csv
normalized_word = pd.read_excel('dataset/normalisasi.xlsx')

# Membuat kamus untuk kata-kata yang dinormalisasi
normalized_word_dict = {}

# Mengisi kamus dengan pasangan kata asal dan kata normalisasi
for index, row in normalized_word.iterrows():
    if row[0] not in normalized_word_dict:
        normalized_word_dict[row[0]] = row[1]

# Fungsi untuk normalisasi term
def normalized_term(document):
    return [normalized_word_dict[term] if term in normalized_word_dict else term for term in document]

# Mengaplikasikan normalisasi pada kolom 'news-tokens-wsw' dan menyimpan hasilnya di kolom 'news-normalized'
pemilu_data['news-normalized'] = pemilu_data['news-tokens-wsw'].apply(normalized_term)

print(pemilu_data['news-normalized'].head())
# Out:
# 0    [dpo, ppln, kuala, lumpur, serahkan, langsung,...
# 1    [pengamat, nilai, prabowogibran, kunci, demokr...
# 2    [hasil, rekapitulasi, provinsi, prabowogibran,...
# 3    [dpr, undang, kpu, rapat, evaluasi, pemilu, re...
# 4     [kris, dayanti, akui, gagal, lolos, dpr, pemilu]
# Name: news-normalized, dtype: object
# C:\Users\M JAWAHIRUL FANANI\AppData\Local\Temp\ipykernel_20924\4115533338.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] not in normalized_word_dict:
# C:\Users\M JAWAHIRUL FANANI\AppData\Local\Temp\ipykernel_20924\4115533338.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   normalized_word_dict[row[0]] = row[1]

# %% [markdown]
# ## Stemmer

# %%
import Sastrawi
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
# import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in pemilu_data['news-normalized']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ''

print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term, ":", term_dict[term])

print(term_dict)
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
# import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in pemilu_data['news-normalized']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ''

# print(len(term_dict))
# print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term, ":", term_dict[term])

# print(term_dict)
# print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return[term_dict[term] for term in document]

pemilu_data['news-tokens-stemmed'] = pemilu_data['news-normalized'].apply(get_stemmed_term)
print(pemilu_data['news-tokens-stemmed'])
# Out:
# 1457
# ------------------------
# dpo : dpo
# ppln : ppln
# kuala : kuala
# lumpur : lumpur
# serahkan : serah
# langsung : langsung
# sidang : sidang
# pn : pn
# jakpus : jakpus
# pengamat : amat
# nilai : nilai
# prabowogibran : prabowogibran
# kunci : kunci
# demokrasi : demokrasi
# indonesia : indonesia
# hasil : hasil
# rekapitulasi : rekapitulasi
# provinsi : provinsi
# sapu : sapu
# bersih : bersih
# kemenangan : menang
# dpr : dpr
# undang : undang
# kpu : kpu
# rapat : rapat
# evaluasi : evaluasi
# pemilu : milu
# selesai : selesai
# kris : kris
# dayanti : dayanti
# akui : aku
# gagal : gagal
# lolos : lolos
# tunda : tunda
# suara : suara
# nasional : nasional
# sulbar : sulbar
# puasa : puasa
# prabowo : prabowo
# unggah : unggah
# foto : foto
# makan : makan
# bareng : bareng
# titiek : titiek
# didit : didit
# airin : airin
# rachmi : rachmi
# caleg : caleg
# dapil : dapil
# banten : banten
# iii : iii
# terpilih : pilih
# ntt : ntt
# nasdem : nasdem
# ratu : ratu
# wulla : wulla
# mengundurkan : undur
# raja : raja
# yordania : yordania
# sapa : sapa
# my : my
# brother : brother
# friend : friend
# selamat : selamat
# mega : mega
# instruksikan : instruksi
# kader : kader
# tertawa : tertawa
# menangis : menang
# rakyat : rakyat
# arahan : arah
# megawati : megawati
# jateng : jateng
# kandang : kandang
# banteng : banteng
# pelopor : pelopor
# konsolidasi : konsolidasi
# pilpres : pilpres
# pdip : pdip
# penuhi : penuh
# jatidiri : jatidiri
# gibran : gibran
# hadiri : hadir
# pemenangan : menang
# ganjar : ganjar
# semarang : semarang
# ganjarpuan : ganjarpuan
# teriakan : ria
# presiden : presiden
# bergema : gema
# anies : anies
# baswedan : baswedan
# rumah : rumah
# sby : sby
# cikeas : cikeas
# bawa : bawa
# buku : buku
# catatan : catat
# video : video
# budiman : budiman
# sudjatmiko : sudjatmiko
# dipecat : pecat
# puan : puan
# urusannya : urus
# pkb : pkb
# ajak : ajak
# bergabung : gabung
# ditawari : tawar
# nyaleg : nyaleg
# demokrat : demokrat
# bahas : bahas
# strategi : strategi
# isi : isi
# pertemuan : temu
# jam : jam
# surya : surya
# paloh : paloh
# momen : momen
# sbyanies : sbyanies
# ri : ri
# mandiri : mandiri
# singgung : singgung
# penelitian : teliti
# iq : iq
# wni : wni
# respons : respons
# survei : survei
# elektabilitas : elektabilitas
# buncit : buncit
# suguhi : suguh
# bakso : bakso
# sukowati : sukowati
# sejarah : sejarah
# berkah : berkah
# pamer : pamer
# tongkat : tongkat
# komando : komando
# simbol : simbol
# amanat : amanat
# karno : karno
# pujapuji : pujapuji
# terobosan : terobos
# infrastruktur : infrastruktur
# jokowi : jokowi
# sat : sat
# set : set
# seruduk : seruduk
# sekat : sekat
# penghambat : hambat
# kemajuan : maju
# negara : negara
# sindir : sindir
# kawan : kawan
# lawan : lawan
# ciut : ciut
# siapkan : siap
# pasukan : pasu
# goronggorong : goronggorong
# burung : burung
# hantu : hantu
# menangkan : menang
# tolahtoleh : tolahtoleh
# disantap : santap
# gema : gema
# tim : tim
# delapan : delapan
# temui : temu
# angkat : angkat
# puji : puji
# kepemimpinan : pimpin
# mk : mk
# izinkan : izin
# kampanye : kampanye
# kampus : kampus
# sekolah : sekolah
# rocky : rocky
# gerung : gerung
# buka : buka
# getarkan : getar
# semangat : semangat
# icw : icw
# berstatus : status
# mantan : mantan
# napi : napi
# korupsi : korupsi
# rk : rk
# golkar : golkar
# melorot : lorot
# turun : turun
# kontemplasi : kontemplasi
# gabung : gabung
# ketum : tum
# forkabi : forkabi
# dukung : dukung
# rektor : rektor
# unhas : unhas
# gelar : gelar
# debat : debat
# diskusi : diskusi
# capres : capres
# izin : izin
# fotonya : foto
# dipasang : pasang
# baliho : baliho
# wali : wali
# kota : kota
# makassar : makassar
# danny : danny
# pomanto : pomanto
# resmi : resmi
# partai : partai
# hanura : hanura
# kunjungi : kunjung
# markas : markas
# denny : denny
# indrayana : indrayana
# laporkan : lapor
# anwar : anwar
# usman : usman
# dugaan : duga
# pelanggaran : langgar
# etik : etik
# politik : politik
# sepekan : pek
# koalisi : koalisi
# pemungutan : mungut
# putaran : putar
# digelar : gelar
# rabu : rabu
# duetkan : duet
# ganjaranies : ganjaranies
# head : head
# to : to
# ramai : ramai
# pintu : pintu
# yusril : yusril
# umumkan : umum
# cawapres : cawapres
# kandidat : kandidat
# nama : nama
# pendukung : dukung
# maju : maju
# zulhas : zulhas
# kenalkan : kenal
# pan : pan
# muhadjir : muhadjir
# erick : erick
# thohir : thohir
# cak : cak
# imin : imin
# hut : hut
# jakarta : jakarta
# airlangga : airlangga
# senang : senang
# gelora : gelora
# bem : bem
# ui : ui
# datangi : datang
# prabowoganjaranies : prabowoganjaranies
# tagih : tagih
# ajakan : aja
# pemenang : menang
# mabes : mabes
# polri : polri
# kirim : kirim
# tambahan : tambah
# papua : papua
# amankan : aman
# hadir : hadir
# deklarasi : deklarasi
# dukungan : dukung
# prabowoerick : prabowoerick
# pidato : pidato
# sudirman : sudirman
# said : said
# kesepakatan : sepakat
# petinggi : petinggi
# parpol : parpol
# pelaku : laku
# dimiskinkan : miskin
# ditakuti : takut
# koruptor : koruptor
# bawaslu : bawaslu
# cek : cek
# data : data
# eks : eks
# daftar : daftar
# forum : forum
# muktamar : muktamar
# sufi : sufi
# internasional : internasional
# ditagih : tagih
# janji : janji
# tkd : tkd
# mahasiswi : mahasiswi
# anak : anak
# pns : pns
# calon : calon
# pengganti : ganti
# ridwan : ridwan
# kamil : kamil
# tunggu : tunggu
# kabar : kabar
# istana : istana
# tersenyum : senyum
# relawan : rawan
# teriak : teriak
# bursa : bursa
# menteri : menteri
# kepala : kepala
# daerah : daerah
# kuliah : kuliah
# kebangsaan : bangsa
# mudamudi : mudamudi
# suarakan : suara
# opini : opini
# the : the
# nation : nation
# fest : fest
# agustus : agustus
# wacana : wacana
# sandi : sandi
# poros : poros
# gandeng : gandeng
# pksdemokrat : pksdemokrat
# ma : ma
# kabulkan : kabul
# uji : uji
# materi : materi
# keterwakilan : wakil
# perempuan : perempuan
# gerindra : gerindra
# pantun : pantun
# jodoh : jodoh
# bicara : bicara
# giliran : gilir
# september : september
# fenomena : fenomena
# golput : golput
# kalangan : kalang
# muda : muda
# mampir : mampir
# depok : depok
# pikir : pikir
# ketemu : ketemu
# bantah : bantah
# warga : warga
# takut : takut
# kritik : kritik
# pemerintah : perintah
# dilarang : larang
# respon : respon
# didukung : dukung
# usung : usung
# pranowo : pranowo
# campuri : campur
# persoalkan : soal
# pakai : pakai
# kuis : kuis
# sepeda : sepeda
# mahasiswa : mahasiswa
# periode : periode
# lsi : lsi
# menetap : tetap
# gaspol : gaspol
# jelang : jelang
# cerita : cerita
# pembentukan : bentuk
# simulasi : simulasi
# coblos : coblos
# pikat : pikat
# cnn : cnn
# putuskan : putus
# pj : pj
# gubernur : gubernur
# pekan : pekan
# rusia : rusia
# audisi : audisi
# putin : putin
# ogah : ogah
# pilih : pilih
# politikus : politikus
# terima : terima
# kasih : kasih
# keras : keras
# potongan : potong
# identifikasi : identifikasi
# pelanjut : lanjut
# pilihan : pilih
# vloc : vloc
# semoga : moga
# representasi : representasi
# firli : firli
# hak : hak
# memilih : pilih
# dipilih : pilih
# mendadak : dadak
# good : good
# news : news
# ojo : ojo
# kesusu : kesusu
# ngalor : ngalor
# ngidul : ngidul
# cocok : cocok
# klik : klik
# personal : personal
# tolak : tolak
# gugatan : gugat
# ketua : ketua
# dogiyai : dogiyai
# rekrutmen : rekrutmen
# anggota : anggota
# kpud : kpud
# kejutan : kejut
# besok : besok
# mayoritas : mayoritas
# pemilih : pilih
# prabowoganjar : prabowoganjar
# jalan : jalan
# beliau : beliau
# beli : beli
# takoyaki : takoyaki
# panggil : panggil
# pilkada : pilkada
# dimajukan : maju
# merusak : rusak
# rencana : rencana
# majukan : maju
# perppu : perppu
# sentil : sentil
# usia : usia
# diputus : putus
# anggaran : anggar
# pengusaha : usaha
# cawecawe : cawecawe
# subianto : subianto
# anggap : anggap
# urgensi : urgensi
# terbitkan : terbit
# mengaku : aku
# dpp : dpp
# sore : sore
# janjikan : janji
# dengar : dengar
# membelot : belot
# aniesnasdem : aniesnasdem
# dikhianati : khianat
# pinang : pinang
# nasdempkb : nasdempkb
# sepakat : sepakat
# kerja : kerja
# pendamping : damping
# rawan : rawan
# negeri : negeri
# maharani : maharani
# sambangi : sambang
# kuda : kuda
# cokelat : cokelat
# kediaman : diam
# ibunda : ibunda
# jombang : jombang
# doa : doa
# senyum : senyum
# khianati : khianat
# perubahan : ubah
# ahyanies : ahyanies
# diturunkan : turun
# surabaya : surabaya
# pasang : pasang
# ragukan : ragu
# pks : pks
# rumor : rumor
# tentukan : tentu
# sikap : sikap
# dikabarkan : kabar
# geram : geram
# husnuzan : husnuzan
# turunkan : turun
# ahy : ahy
# malam : malam
# kaget : kaget
# aniescak : aniescak
# duet : duet
# elite : elite
# dirangkul : rangkul
# damai : damai
# diisukan : isu
# tegaskan : tegas
# taat : taat
# aturan : atur
# kamar : kamar
# kelahiran : lahir
# gus : gus
# dur : dur
# beda : beda
# mejeng : mejeng
# jubir : jubir
# bakat : bakat
# pengkhianat : khianat
# cianjur : cianjur
# copot : copot
# campur : campur
# keretakan : kereta
# pengusung : usung
# surat : surat
# tulis : tulis
# tangan : tangan
# hengkang : hengkang
# bicarakan : bicara
# baikbaik : baikbaik
# sepucuk : pucuk
# poinpoin : poinpoin
# jumpa : jumpa
# salah : salah
# alamat : alamat
# gugat : gugat
# batas : batas
# caprescawapres : caprescawapres
# muhaimin : muhaimin
# dampingi : damping
# orang : orang
# ungkit : ungkit
# guru : guru
# spiritual : spiritual
# bisiki : bisik
# geger : geger
# isu : isu
# ppp : ppp
# demokratpks : demokratpks
# masuk : masuk
# diatur : atur
# paslon : paslon
# ingatkan : ingat
# era : era
# alasan : alas
# arti : arti
# lukisan : lukis
# no : no
# justice : justice
# peace : peace
# bentrok : bentrok
# kepentingan : penting
# larangan : larang
# berpasangan : pasang
# otomatis : otomatis
# pamit : pamit
# jejak : jejak
# pingit : pingit
# tandatanda : tandatanda
# bergejolak : gejolak
# kamis : kamis
# pleno : pleno
# sambut : sambut
# tawaran : tawar
# sejateng : sejateng
# copoti : copot
# gambar : gambar
# kiamat : kiamat
# sekjen : sekjen
# bertemu : temu
# emosional : emosional
# makna : makna
# seekor : ekor
# pimpin : pimpin
# merapat : rapat
# garuda : garuda
# menunggu : tunggu
# sragen : sragen
# bakar : bakar
# bergambar : gambar
# cabut : cabut
# diperingatkan : ingat
# kepercayaan : percaya
# potensi : potensi
# mengekor : ekor
# kemanapun : mana
# melangkah : lang
# lewati : lewat
# kepatutan : patut
# moral : moral
# etika : etika
# komunikasi : komunikasi
# percaya : percaya
# menyangka : sangka
# berkhianat : khianat
# jujur : jujur
# amanah : amanah
# batal : batal
# komentari : komentar
# belok : belok
# sein : sein
# lobi : lobi
# bentuk : bentuk
# setuju : tuju
# bongkar : bongkar
# reaksi : reaksi
# polisi : polisi
# info : info
# acara : acara
# manuver : manuver
# ketebak : tebak
# spontan : spontan
# keberatan : berat
# program : program
# akhirakhir : akhirakhir
# sarat : sarat
# aroma : aroma
# pengkhianatan : khianat
# pasangan : pasang
# dihadiri : hadir
# sekutu : sekutu
# kisruh : kisruh
# berujung : ujung
# pergi : pergi
# gabungdemokrat : gabungdemokrat
# lengkap : lengkap
# seberang : seberang
# lokasi : lokasi
# yahya : yahya
# nu : nu
# rebutan : rebut
# kebo : kebo
# aniespaloh : aniespaloh
# salim : salim
# segaf : segaf
# ikhlas : ikhlas
# dighosting : dighosting
# maaf : maaf
# hormati : hormat
# hotel : hotel
# majapahit : majapahit
# jomblo : jomblo
# ganggu : ganggu
# pbnu : pbnu
# panggung : panggung
# bacapres : bacapres
# munas : munas
# konbes : konbes
# berpeluang : peluang
# impor : impor
# energi : energi
# menang : menang
# ummat : ummat
# beberkan : kan
# alasanalasan : alasanalasan
# pekik : pekik
# merdeka : merdeka
# pindah : pindah
# gerbong : gerbong
# upaya : upaya
# jegal : jegal
# hukum : hukum
# ihza : ihza
# mahendra : mahendra
# alternatif : alternatif
# kutip : kutip
# ucapan : ucap
# kumpul : kumpul
# otorita : otorita
# pembangunan : bangun
# ikn : ikn
# terganggu : ganggu
# pergantian : ganti
# pakar : pakar
# kemas : kemas
# ulang : ulang
# narasi : narasi
# intensif : intensif
# tinggalkan : tinggal
# ribuan : ribu
# bosan : bosan
# zikir : zikir
# ucapkan : ucap
# pbb : pbb
# didorong : dorong
# putri : putri
# gusdurian : gusdurian
# organisasi : organisasi
# terganjal : ganjal
# hubungan : hubung
# sbymega : sbymega
# condong : condong
# bareskrim : bareskrim
# wajibkan : wajib
# peserta : serta
# pemilupilpres : pemilupilpres
# bangun : bangun
# budaya : budaya
# bermartabat : martabat
# terbuka : buka
# perhitungkan : hitung
# usul : usul
# lantunkan : lantun
# bento : bento
# pengamen : amen
# jalanan : jalan
# lengser : lengser
# wagub : wagub
# sumut : sumut
# ijeck : ijeck
# fokus : fokus
# klaim : klaim
# psi : psi
# wa : wa
# agree : agree
# disagree : disagree
# dipaksa : paksa
# nyatakan : nyata
# move : move
# on : on
# ja : ja
# favorit : favorit
# ketiga : tiga
# maafkan : maaf
# sakiti : sakit
# sukses : sukses
# sahroni : sahroni
# kecewa : kecewa
# kepedean : kepedean
# pemimpin : pimpin
# pemersatu : satu
# umat : umat
# sesuai : sesuai
# kriteria : kriteria
# menaq : menaq
# yaqut : yaqut
# setia : setia
# pagi : pagi
# tempe : tempe
# rp : rp
# gaji : gaji
# pegawai : pegawai
# perjuangan : juang
# dilukai : luka
# pamitan : pamit
# seruuu : seruuu
# banget : banget
# ngobrolnya : ngobrolnya
# insya : insya
# allah : allah
# songsong : songsong
# perjalanan : jalan
# penentuan : tentu
# hitungan : hitung
# menit : menit
# ketimbang : ketimbang
# aktivis : aktivis
# bukabukaan : bukabukaan
# jabatan : jabat
# koster : koster
# istirahat : istirahat
# tancap : tancap
# gas : gas
# urus : urus
# ambigu : ambigu
# beban : beban
# publik : publik
# rancangan : rancang
# pkpu : pkpu
# grace : grace
# drama : drama
# sinetron : sinetron
# profil : profil
# arsjad : arsjad
# rasjid : rasjid
# peluang : peluang
# pertemukan : temu
# aset : aset
# harap : harap
# cari : cari
# draf : draf
# pendaftaran : daftar
# oktober : oktober
# andika : andika
# perkasa : perkasa
# diberitahu : diberitahu
# wakil : wakil
# direstui : restu
# kiai : kiai
# khos : khos
# purworejo : purworejo
# puncak : puncak
# perbedaan : beda
# buntu : buntu
# gebrak : gebrak
# meja : meja
# panas : panas
# curiga : curiga
# intervensi : intervensi
# jadwal : jadwal
# ancam : ancam
# sanksi : sanksi
# pengurus : urus
# bawabawa : bawabawa
# tpn : tpn
# paham : paham
# radar : radar
# sulit : sulit
# yenny : yenny
# wasiat : wasiat
# wafat : wafat
# diganti : ganti
# masyumi : masyumi
# tower : tower
# diulangi : ulang
# wahid : wahid
# dikudeta : kudeta
# temanteman : temanteman
# menerus : terus
# blakblakan : blakblakan
# intrik : intrik
# kudeta : kudeta
# benny : benny
# harman : harman
# jahat : jahat
# breaking : breaking
# mohon : mohon
# maklum : maklum
# siang : siang
# rancang : rancang
# dinamis : dinamis
# panggilan : panggil
# kpk : kpk
# murni : murni
# mtq : mtq
# duga : duga
# intimidasi : intimidasi
# opsi : opsi
# berhak : hak
# larang : larang
# warganya : warga
# ngaku : ngaku
# jeda : jeda
# tugas : tugas
# jawa : jawa
# barat : barat
# tito : tito
# dipercepat : cepat
# dudung : dudung
# purnawirawan : purnawirawan
# pengaruhi : pengaruh
# prajurit : prajurit
# aktif : aktif
# imbauan : imbau
# menag : menag
# mas : mas
# persis : persis
# kertanegara : kertanegara
# prabowoyenny : prabowoyenny
# balas : balas
# hormat : hormat
# disambut : sambut
# komisioner : komisioner
# laporan : lapor
# dkpp : dkpp
# tahapan : tahap
# kronologi : kronologi
# ditolak : tolak
# marah : marah
# kumpulkan : kumpul
# dpd : dpd
# seindonesia : indonesia
# arah : arah
# rebut : rebut
# hati : hati
# selawat : selawat
# kantor : kantor
# tahap : tahap
# disahkan : sah
# clbk : clbk
# kehormatan : hormat
# bersuara : suara
# political : political
# road : road
# show : show
# part : part
# staquf : staquf
# lahir : lahir
# sepakati : sepakat
# identitas : identitas
# optimis : optimis
# diterima : terima
# majelis : majelis
# syuro : syuro
# restu : restu
# jatim : jatim
# pmii : pmii
# hashim : hashim
# gratis : gratis
# butuh : butuh
# kyai : kyai
# simpati : simpati
# kasad : kasad
# kode : kode
# mukjizat : mukjizat
# kompas : kompas
# pdipganjar : pdipganjar
# gerindraprabowo : gerindraprabowo
# minggu : minggu
# as : as
# soroti : sorot
# khofifah : khofifah
# ajukan : aju
# diperiksa : periksa
# andi : andi
# arief : arief
# usulkan : usul
# timses : timses
# sing : sing
# sabar : sabar
# buton : buton
# kondisi : kondisi
# mabuk : mabuk
# figur : figur
# aniesmuhaimin : aniesmuhaimin
# strategis : strategis
# wujudkan : wujud
# tipis : tipis
# kans : kans
# mundur : mundur
# ambisi : ambisi
# pertimbangan : timbang
# berharap : harap
# pilar : pilar
# utama : utama
# persatuan : satu
# kuat : kuat
# megawatisby : megawatisby
# barikade : barikade
# tinggal : tinggal
# pengemudi : kemudi
# ojol : ojol
# pastikan : pasti
# bersedia : sedia
# aqil : aqil
# heran : heran
# periksa : periksa
# kemarinkemarin : kemarinkemarin
# ketuk : ketuk
# teuku : teuku
# umar : umar
# ulama : ulama
# kharismatik : kharismatik
# kh : kh
# thoifur : thoifur
# kubu : kubu
# mempersatukan : satu
# kehadiran : hadir
# mahfud : mahfud
# md : md
# bertengkar : tengkar
# safari : safari
# tuding : tuding
# lemah : lemah
# bapaknya : bapak
# kena : kena
# ghosting : ghosting
# hasto : hasto
# berpolitik : politik
# praktis : praktis
# berat : berat
# peta : peta
# pemilik : milik
# mendagri : mendagri
# percepatan : cepat
# berisiko : risiko
# muncul : muncul
# tayangan : tayang
# azan : azan
# tv : tv
# perindo : perindo
# seruan : seru
# kebaikan : baik
# sandiaga : sandiaga
# uno : uno
# utusan : utus
# berpotensi : potensi
# ditugasi : tugas
# miftah : miftah
# lagu : lagu
# capresku : capresku
# jadwalkan : jadwal
# maman : maman
# pembaruan : baru
# berkelanjutan : lanjut
# niat : niat
# enggan : enggan
# komentar : komentar
# kpi : kpi
# polling : polling
# institute : institute
# terkuat : kuat
# tokoh : tokoh
# bamsoet : bamsoet
# terjebak : jebak
# transaksional : transaksional
# nomor : nomor
# piro : piro
# wani : wani
# ngopi : ngopi
# unggul : unggul
# syaratkan : syarat
# surati : surati
# stasiun : stasiun
# klarifikasi : klarifikasi
# sosok : sosok
# penggebrak : gebrak
# alot : alot
# jatah : jatah
# cair : cair
# sebaran : sebar
# pulau : pulau
# sumatera : sumatera
# dana : dana
# desa : desa
# miliar : miliar
# hidayat : hidayat
# nur : nur
# akur : akur
# lancar : lancar
# menguat : kuat
# arsul : arsul
# candaan : canda
# berubah : ubah
# kunjungan : kunjung
# perdana : perdana
# sowan : sowan
# didoakan : doa
# wapres : wapres
# siratkan : sirat
# timur : timur
# naikkan : naik
# usulan : usul
# dibahas : bahas
# ujugujug : ujugujug
# fahri : fahri
# hamzah : hamzah
# menindak : tindak
# bebas : bebas
# dagang : dagang
# sapi : sapi
# maruf : maruf
# amin : amin
# media : media
# penyiaran : siar
# santai : santai
# posisi : posisi
# hasilnya : hasil
# komisi : komisi
# ii : ii
# peremajaan : remaja
# videojokowi : videojokowi
# nyapres : nyapres
# fasilitas : fasilitas
# tsamara : tsamara
# amany : amany
# saksi : saksi
# agum : agum
# gumelar : gumelar
# pepabri : pepabri
# netral : netral
# semut : semut
# merah : merah
# berlari : lari
# jas : jas
# biru : biru
# duduk : duduk
# bersebelahan : bahan
# nyanyi : nyanyi
# kspsi : kspsi
# megasby : megasby
# bola : bola
# panda : panda
# utang : utang
# diberesin : resin
# diungkit : ungkit
# nababan : nababan
# libur : libur
# pencoblosan : coblos
# sukmawati : sukmawati
# bagus : bagus
# absen : absen
# titip : titip
# pesan : pesan
# ahmad : ahmad
# syaikhu : syaikhu
# ciptaan : cipta
# agama : agama
# bela : bela
# kuncinya : kunci
# bandingkan : banding
# rempang : rempang
# kampung : kampung
# akuarium : akuarium
# luka : luka
# mendalam : dalam
# peran : peran
# gocapan : gocap
# uang : uang
# sedekah : sedekah
# sbyprabowo : sbyprabowo
# karaoke : karaoke
# mufakat : mufakat
# bagibagi : bagibagi
# waketum : waketum
# panglima : panglima
# atribut : atribut
# tni : tni
# mengerucut : kerucut
# dibicarakan : bicara
# tempel : tempel
# stiker : stiker
# maluku : malu
# wajar : wajar
# dikerjai : kerja
# menjanjikan : janji
# menhan : menhan
# bagja : bagja
# terlibat : libat
# kkb : kkb
# lanjutkan : lanjut
# misi : misi
# habibie : habibie
# pesawat : pesawat
# santri : santri
# tiktok : tiktok
# langgar : langgar
# dijatuhi : jatuh
# peringatan : ingat
# sediakan : sedia
# rilis : rilis
# bacawapres : bacawapres
# tgb : tgb
# konflik : konflik
# pengakuan : aku
# diundang : undang
# berebut : rebut
# kesempatan : sempat
# menpan : menpan
# rb : rb
# jaga : jaga
# netralitas : netralitas
# asn : asn
# kemendagri : kemendagri
# tanggal : tanggal
# setujui : tuju
# bahaya : bahaya
# timnas : timnas
# wakapolri : wakapolri
# petunjuk : tunjuk
# wo : wo
# canda : canda
# bidah : bidah
# ambil : ambil
# keputusan : putus
# rekam : rekam
# jaksa : jaksa
# agung : agung
# prasetyo : prasetyo
# dewan : dewan
# pengarah : arah
# semalam : malam
# dikawal : kawal
# jenderal : jenderal
# pensiunan : pensiun
# tnipolri : tnipolri
# perkuat : kuat
# jabar : jabar
# khawatir : khawatir
# radikalisme : radikalisme
# dianggap : anggap
# ikatan : ikat
# lengkapi : lengkap
# struktur : struktur
# menyusul : susul
# tegur : tegur
# ganjarridwan : ganjarridwan
# menguntungkan : untung
# dilibatkan : libat
# berencana : rencana
# avengers : avengers
# geleng : geleng
# guyon : guyon
# adu : adu
# versi : versi
# amien : amien
# rais : rais
# sumbar : sumbar
# sosialisasi : sosialisasi
# parlemen : parlemen
# buruh : buruh
# hapus : hapus
# presidential : presidential
# threshold : threshold
# magrib : magrib
# videonya : video
# viral : viral
# zulkifli : zulkifli
# hasan : hasan
# prabowork : prabowork
# urusan : urus
# golkarpan : golkarpan
# terendah : rendah
# smrc : smrc
# dki : dki
# rendah : rendah
# aniesimin : aniesimin
# keempat : empat
# dinilai : nilai
# diklaim : klaim
# menikmati : nikmat
# underdog : underdog
# ppatk : ppatk
# berambisi : ambisi
# kekuatan : kuat
# kejahatan : jahat
# guyonan : guyon
# terbaru : baru
# syarat : syarat
# apapun : apa
# dibolehkan : boleh
# lempar : lempar
# dipimpin : pimpin
# lakilaki : lakilaki
# tampan : tampan
# fisip : fisip
# diusung : usung
# optimistis : optimistis
# raih : raih
# juta : juta
# basis : basis
# jabarjakarta : jabarjakarta
# paparkan : papar
# dalih : dalih
# sahabat : sahabat
# pria : pria
# jeroan : jeroan
# berkat : berkat
# bin : bin
# bais : bais
# relakan : rela
# madrasah : madrasah
# penyuluh : suluh
# dipakai : pakai
# tugaskan : tugas
# tarung : tarung
# hambalang : hambalang
# mari : mari
# jemput : jemput
# gunung : gunung
# plus : plus
# minus : minus
# agamawan : agamawan
# wiranto : wiranto
# gagas : gagas
# kenaikan : naik
# bumn : bumn
# gemuk : gemuk
# jamin : jamin
# munaskonbes : munaskonbes
# informasi : informasi
# intelijen : intelijen
# dimiliki : milik
# rapimnas : rapimnas
# diputuskan : putus
# artis : artis
# bertarung : tarung
# uya : uya
# kuya : kuya
# pasha : pasha
# ungu : ungu
# tertutup : tutup
# menyumbang : sumbang
# dibatasi : batas
# kahmi : kahmi
# gagasan : gagas
# effendy : effendy
# najwa : najwa
# shihab : shihab
# menyeberang : seberang
# petugas : tugas
# lihat : lihat
# layanan : layan
# ai : ai
# kayak : kayak
# jazilul : jazilul
# boneka : boneka
# pertimbangkan : timbang
# jabat : jabat
# berjodoh : jodoh
# perjuangkan : juang
# perbaikan : baik
# tka : tka
# china : china
# infografis : infografis
# tpsmobilisasi : tpsmobilisasi
# kapolri : kapolri
# undangan : undang
# investasi : investasi
# rugikan : rugi
# masyarakat : masyarakat
# hinca : hinca
# sbymegawati : sbymegawati
# akun : akun
# kebun : kebun
# binatang : binatang
# diretas : retas
# posting : posting
# ugm : ugm
# kim : kim
# dijadwalkan : jadwal
# agraria : agraria
# tercatat : catat
# penyalahgunaan : penyalahgunaan
# sarapan : sarap
# anggapan : anggap
# kemiskinan : miskin
# ekstrem : ekstrem
# mesti : mesti
# nol : nol
# turis : turis
# bali : bal
# kontribusi : kontribusi
# masukkan : masuk
# byebye : byebye
# kualitas : kualitas
# sdm : sdm
# gantikan : ganti
# ig : ig
# promosikan : promosi
# mnc : mnc
# kelakar : kelakar
# sri : sri
# mulyani : mulyani
# banggar : banggar
# koleksi : koleksi
# kendaraan : kendara
# siaran : siar
# populer : populer
# ormas : ormas
# islam : islam
# rekomendasi : rekomendasi
# muhammadiyah : muhammadiyah
# projo : projo
# rahasia : rahasia
# dicoret : coret
# ribu : ribu
# suka : suka
# cekik : cekik
# wamen : wamen
# ngerti : ngerti
# fitnah : fitnah
# kerap : kerap
# diejek : ejek
# pusing : pusing
# urut : urut
# terpengaru : aru
# alifurrahman : alifurrahman
# sebar : sebar
# cekiktampar : cekiktampar
# jual : jual
# biayai : biaya
# permintaan : minta
# tempuh : tempuh
# tom : tom
# lembong : lembong
# reindustrialisasi : reindustrialisasi
# padat : padat
# karya : karya
# kurangi : kurang
# pengangguran : anggur
# cetak : cetak
# kaesang : kaesang
# persiapan : siap
# curhat : curhat
# ngaji : ngaji
# sediy : sediy
# kesal : kesal
# difitnah : fitnah
# ganti : ganti
# visi : visi
# ragu : ragu
# didaftarkan : daftar
# bantahan : bantah
# kemenkeu : kemenkeu
# catut : catut
# timbulkan : timbul
# keresahan : resah
# deadlock : deadlock
# afgan : afgan
# terapkan : terap
# hitung : hitung
# panel : panel
# percepat : cepat
# diwarnai : warna
# perdebatan : debat
# jcc : jcc
# senayan : senayan
# rudi : rudi
# kamri : kamri
# pendidikan : didik
# gizi : gizi
# depresi : depresi
# kepikiran : pikir
# situ : situ
# susah : susah
# terwujud : wujud
# darurat : darurat
# cipta : cipta
# kalkulasi : kalkulasi
# kominfo : kominfo
# hoaks : hoaks
# takedown : takedown
# solo : solo
# wajah : wajah
# bro : bro
# sutiyoso : sutiyoso
# konsisten : konsisten
# berani : berani
# kukuh : kukuh
# peneliti : teliti
# brin : brin
# terindikasi : indikasi
# peluk : peluk
# last : last
# minute : mute
# barus : barus
# cenderung : cenderung
# benarkan : benar
# disepakati : pakat
# titipan : titip
# natalie : natalie
# kta : kta
# ganjarprabowo : ganjarprabowo
# mengubah : ubah
# ekonomi : ekonomi
# absolut : absolut
# joget : joget
# harapan : harap
# videokaesang : videokaesang
# djarot : djarot
# keluarga : keluarga
# baja : baja
# berisi : isi
# pelukis : peluk
# musyawarah : musyawarah
# analisis : analisis
# medsos : medsos
# drone : drone
# emprit : emprit
# buruk : buruk
# bangsa : bangsa
# persen : persen
# menyongsong : songsong
# sadar : sadar
# superman : superman
# supertim : supertim
# {'dpo': 'dpo', 'ppln': 'ppln', 'kuala': 'kuala', 'lumpur': 'lumpur', 'serahkan': 'serah', 'langsung': 'langsung', 'sidang': 'sidang', 'pn': 'pn', 'jakpus': 'jakpus', 'pengamat': 'amat', 'nilai': 'nilai', 'prabowogibran': 'prabowogibran', 'kunci': 'kunci', 'demokrasi': 'demokrasi', 'indonesia': 'indonesia', 'hasil': 'hasil', 'rekapitulasi': 'rekapitulasi', 'provinsi': 'provinsi', 'sapu': 'sapu', 'bersih': 'bersih', 'kemenangan': 'menang', 'dpr': 'dpr', 'undang': 'undang', 'kpu': 'kpu', 'rapat': 'rapat', 'evaluasi': 'evaluasi', 'pemilu': 'milu', 'selesai': 'selesai', 'kris': 'kris', 'dayanti': 'dayanti', 'akui': 'aku', 'gagal': 'gagal', 'lolos': 'lolos', 'tunda': 'tunda', 'suara': 'suara', 'nasional': 'nasional', 'sulbar': 'sulbar', 'puasa': 'puasa', 'prabowo': 'prabowo', 'unggah': 'unggah', 'foto': 'foto', 'makan': 'makan', 'bareng': 'bareng', 'titiek': 'titiek', 'didit': 'didit', 'airin': 'airin', 'rachmi': 'rachmi', 'caleg': 'caleg', 'dapil': 'dapil', 'banten': 'banten', 'iii': 'iii', 'terpilih': 'pilih', 'ntt': 'ntt', 'nasdem': 'nasdem', 'ratu': 'ratu', 'wulla': 'wulla', 'mengundurkan': 'undur', 'raja': 'raja', 'yordania': 'yordania', 'sapa': 'sapa', 'my': 'my', 'brother': 'brother', 'friend': 'friend', 'selamat': 'selamat', 'mega': 'mega', 'instruksikan': 'instruksi', 'kader': 'kader', 'tertawa': 'tertawa', 'menangis': 'menang', 'rakyat': 'rakyat', 'arahan': 'arah', 'megawati': 'megawati', 'jateng': 'jateng', 'kandang': 'kandang', 'banteng': 'banteng', 'pelopor': 'pelopor', 'konsolidasi': 'konsolidasi', 'pilpres': 'pilpres', 'pdip': 'pdip', 'penuhi': 'penuh', 'jatidiri': 'jatidiri', 'gibran': 'gibran', 'hadiri': 'hadir', 'pemenangan': 'menang', 'ganjar': 'ganjar', 'semarang': 'semarang', 'ganjarpuan': 'ganjarpuan', 'teriakan': 'ria', 'presiden': 'presiden', 'bergema': 'gema', 'anies': 'anies', 'baswedan': 'baswedan', 'rumah': 'rumah', 'sby': 'sby', 'cikeas': 'cikeas', 'bawa': 'bawa', 'buku': 'buku', 'catatan': 'catat', 'video': 'video', 'budiman': 'budiman', 'sudjatmiko': 'sudjatmiko', 'dipecat': 'pecat', 'puan': 'puan', 'urusannya': 'urus', 'pkb': 'pkb', 'ajak': 'ajak', 'bergabung': 'gabung', 'ditawari': 'tawar', 'nyaleg': 'nyaleg', 'demokrat': 'demokrat', 'bahas': 'bahas', 'strategi': 'strategi', 'isi': 'isi', 'pertemuan': 'temu', 'jam': 'jam', 'surya': 'surya', 'paloh': 'paloh', 'momen': 'momen', 'sbyanies': 'sbyanies', 'ri': 'ri', 'mandiri': 'mandiri', 'singgung': 'singgung', 'penelitian': 'teliti', 'iq': 'iq', 'wni': 'wni', 'respons': 'respons', 'survei': 'survei', 'elektabilitas': 'elektabilitas', 'buncit': 'buncit', 'suguhi': 'suguh', 'bakso': 'bakso', 'sukowati': 'sukowati', 'sejarah': 'sejarah', 'berkah': 'berkah', 'pamer': 'pamer', 'tongkat': 'tongkat', 'komando': 'komando', 'simbol': 'simbol', 'amanat': 'amanat', 'karno': 'karno', 'pujapuji': 'pujapuji', 'terobosan': 'terobos', 'infrastruktur': 'infrastruktur', 'jokowi': 'jokowi', 'sat': 'sat', 'set': 'set', 'seruduk': 'seruduk', 'sekat': 'sekat', 'penghambat': 'hambat', 'kemajuan': 'maju', 'negara': 'negara', 'sindir': 'sindir', 'kawan': 'kawan', 'lawan': 'lawan', 'ciut': 'ciut', 'siapkan': 'siap', 'pasukan': 'pasu', 'goronggorong': 'goronggorong', 'burung': 'burung', 'hantu': 'hantu', 'menangkan': 'menang', 'tolahtoleh': 'tolahtoleh', 'disantap': 'santap', 'gema': 'gema', 'tim': 'tim', 'delapan': 'delapan', 'temui': 'temu', 'angkat': 'angkat', 'puji': 'puji', 'kepemimpinan': 'pimpin', 'mk': 'mk', 'izinkan': 'izin', 'kampanye': 'kampanye', 'kampus': 'kampus', 'sekolah': 'sekolah', 'rocky': 'rocky', 'gerung': 'gerung', 'buka': 'buka', 'getarkan': 'getar', 'semangat': 'semangat', 'icw': 'icw', 'berstatus': 'status', 'mantan': 'mantan', 'napi': 'napi', 'korupsi': 'korupsi', 'rk': 'rk', 'golkar': 'golkar', 'melorot': 'lorot', 'turun': 'turun', 'kontemplasi': 'kontemplasi', 'gabung': 'gabung', 'ketum': 'tum', 'forkabi': 'forkabi', 'dukung': 'dukung', 'rektor': 'rektor', 'unhas': 'unhas', 'gelar': 'gelar', 'debat': 'debat', 'diskusi': 'diskusi', 'capres': 'capres', 'i ...
# dpo : dpo
# ppln : ppln
# kuala : kuala
# lumpur : lumpur
# serahkan : serah
# langsung : langsung
# sidang : sidang
# pn : pn
# jakpus : jakpus
# pengamat : amat
# nilai : nilai
# prabowogibran : prabowogibran
# kunci : kunci
# demokrasi : demokrasi
# indonesia : indonesia
# hasil : hasil
# rekapitulasi : rekapitulasi
# provinsi : provinsi
# sapu : sapu
# bersih : bersih
# kemenangan : menang
# dpr : dpr
# undang : undang
# kpu : kpu
# rapat : rapat
# evaluasi : evaluasi
# pemilu : milu
# selesai : selesai
# kris : kris
# dayanti : dayanti
# akui : aku
# gagal : gagal
# lolos : lolos
# tunda : tunda
# suara : suara
# nasional : nasional
# sulbar : sulbar
# puasa : puasa
# prabowo : prabowo
# unggah : unggah
# foto : foto
# makan : makan
# bareng : bareng
# titiek : titiek
# didit : didit
# airin : airin
# rachmi : rachmi
# caleg : caleg
# dapil : dapil
# banten : banten
# iii : iii
# terpilih : pilih
# ntt : ntt
# nasdem : nasdem
# ratu : ratu
# wulla : wulla
# mengundurkan : undur
# raja : raja
# yordania : yordania
# sapa : sapa
# my : my
# brother : brother
# friend : friend
# selamat : selamat
# mega : mega
# instruksikan : instruksi
# kader : kader
# tertawa : tertawa
# menangis : menang
# rakyat : rakyat
# arahan : arah
# megawati : megawati
# jateng : jateng
# kandang : kandang
# banteng : banteng
# pelopor : pelopor
# konsolidasi : konsolidasi
# pilpres : pilpres
# pdip : pdip
# penuhi : penuh
# jatidiri : jatidiri
# gibran : gibran
# hadiri : hadir
# pemenangan : menang
# ganjar : ganjar
# semarang : semarang
# ganjarpuan : ganjarpuan
# teriakan : ria
# presiden : presiden
# bergema : gema
# anies : anies
# baswedan : baswedan
# rumah : rumah
# sby : sby
# cikeas : cikeas
# bawa : bawa
# buku : buku
# catatan : catat
# video : video
# budiman : budiman
# sudjatmiko : sudjatmiko
# dipecat : pecat
# puan : puan
# urusannya : urus
# pkb : pkb
# ajak : ajak
# bergabung : gabung
# ditawari : tawar
# nyaleg : nyaleg
# demokrat : demokrat
# bahas : bahas
# strategi : strategi
# isi : isi
# pertemuan : temu
# jam : jam
# surya : surya
# paloh : paloh
# momen : momen
# sbyanies : sbyanies
# ri : ri
# mandiri : mandiri
# singgung : singgung
# penelitian : teliti
# iq : iq
# wni : wni
# respons : respons
# survei : survei
# elektabilitas : elektabilitas
# buncit : buncit
# suguhi : suguh
# bakso : bakso
# sukowati : sukowati
# sejarah : sejarah
# berkah : berkah
# pamer : pamer
# tongkat : tongkat
# komando : komando
# simbol : simbol
# amanat : amanat
# karno : karno
# pujapuji : pujapuji
# terobosan : terobos
# infrastruktur : infrastruktur
# jokowi : jokowi
# sat : sat
# set : set
# seruduk : seruduk
# sekat : sekat
# penghambat : hambat
# kemajuan : maju
# negara : negara
# sindir : sindir
# kawan : kawan
# lawan : lawan
# ciut : ciut
# siapkan : siap
# pasukan : pasu
# goronggorong : goronggorong
# burung : burung
# hantu : hantu
# menangkan : menang
# tolahtoleh : tolahtoleh
# disantap : santap
# gema : gema
# tim : tim
# delapan : delapan
# temui : temu
# angkat : angkat
# puji : puji
# kepemimpinan : pimpin
# mk : mk
# izinkan : izin
# kampanye : kampanye
# kampus : kampus
# sekolah : sekolah
# rocky : rocky
# gerung : gerung
# buka : buka
# getarkan : getar
# semangat : semangat
# icw : icw
# berstatus : status
# mantan : mantan
# napi : napi
# korupsi : korupsi
# rk : rk
# golkar : golkar
# melorot : lorot
# turun : turun
# kontemplasi : kontemplasi
# gabung : gabung
# ketum : tum
# forkabi : forkabi
# dukung : dukung
# rektor : rektor
# unhas : unhas
# gelar : gelar
# debat : debat
# diskusi : diskusi
# capres : capres
# izin : izin
# fotonya : foto
# dipasang : pasang
# baliho : baliho
# wali : wali
# kota : kota
# makassar : makassar
# danny : danny
# pomanto : pomanto
# resmi : resmi
# partai : partai
# hanura : hanura
# kunjungi : kunjung
# markas : markas
# denny : denny
# indrayana : indrayana
# laporkan : lapor
# anwar : anwar
# usman : usman
# dugaan : duga
# pelanggaran : langgar
# etik : etik
# politik : politik
# sepekan : pek
# koalisi : koalisi
# pemungutan : mungut
# putaran : putar
# digelar : gelar
# rabu : rabu
# duetkan : duet
# ganjaranies : ganjaranies
# head : head
# to : to
# ramai : ramai
# pintu : pintu
# yusril : yusril
# umumkan : umum
# cawapres : cawapres
# kandidat : kandidat
# nama : nama
# pendukung : dukung
# maju : maju
# zulhas : zulhas
# kenalkan : kenal
# pan : pan
# muhadjir : muhadjir
# erick : erick
# thohir : thohir
# cak : cak
# imin : imin
# hut : hut
# jakarta : jakarta
# airlangga : airlangga
# senang : senang
# gelora : gelora
# bem : bem
# ui : ui
# datangi : datang
# prabowoganjaranies : prabowoganjaranies
# tagih : tagih
# ajakan : aja
# pemenang : menang
# mabes : mabes
# polri : polri
# kirim : kirim
# tambahan : tambah
# papua : papua
# amankan : aman
# hadir : hadir
# deklarasi : deklarasi
# dukungan : dukung
# prabowoerick : prabowoerick
# pidato : pidato
# sudirman : sudirman
# said : said
# kesepakatan : sepakat
# petinggi : petinggi
# parpol : parpol
# pelaku : laku
# dimiskinkan : miskin
# ditakuti : takut
# koruptor : koruptor
# bawaslu : bawaslu
# cek : cek
# data : data
# eks : eks
# daftar : daftar
# forum : forum
# muktamar : muktamar
# sufi : sufi
# internasional : internasional
# ditagih : tagih
# janji : janji
# tkd : tkd
# mahasiswi : mahasiswi
# anak : anak
# pns : pns
# calon : calon
# pengganti : ganti
# ridwan : ridwan
# kamil : kamil
# tunggu : tunggu
# kabar : kabar
# istana : istana
# tersenyum : senyum
# relawan : rawan
# teriak : teriak
# bursa : bursa
# menteri : menteri
# kepala : kepala
# daerah : daerah
# kuliah : kuliah
# kebangsaan : bangsa
# mudamudi : mudamudi
# suarakan : suara
# opini : opini
# the : the
# nation : nation
# fest : fest
# agustus : agustus
# wacana : wacana
# sandi : sandi
# poros : poros
# gandeng : gandeng
# pksdemokrat : pksdemokrat
# ma : ma
# kabulkan : kabul
# uji : uji
# materi : materi
# keterwakilan : wakil
# perempuan : perempuan
# gerindra : gerindra
# pantun : pantun
# jodoh : jodoh
# bicara : bicara
# giliran : gilir
# september : september
# fenomena : fenomena
# golput : golput
# kalangan : kalang
# muda : muda
# mampir : mampir
# depok : depok
# pikir : pikir
# ketemu : ketemu
# bantah : bantah
# warga : warga
# takut : takut
# kritik : kritik
# pemerintah : perintah
# dilarang : larang
# respon : respon
# didukung : dukung
# usung : usung
# pranowo : pranowo
# campuri : campur
# persoalkan : soal
# pakai : pakai
# kuis : kuis
# sepeda : sepeda
# mahasiswa : mahasiswa
# periode : periode
# lsi : lsi
# menetap : tetap
# gaspol : gaspol
# jelang : jelang
# cerita : cerita
# pembentukan : bentuk
# simulasi : simulasi
# coblos : coblos
# pikat : pikat
# cnn : cnn
# putuskan : putus
# pj : pj
# gubernur : gubernur
# pekan : pekan
# rusia : rusia
# audisi : audisi
# putin : putin
# ogah : ogah
# pilih : pilih
# politikus : politikus
# terima : terima
# kasih : kasih
# keras : keras
# potongan : potong
# identifikasi : identifikasi
# pelanjut : lanjut
# pilihan : pilih
# vloc : vloc
# semoga : moga
# representasi : representasi
# firli : firli
# hak : hak
# memilih : pilih
# dipilih : pilih
# mendadak : dadak
# good : good
# news : news
# ojo : ojo
# kesusu : kesusu
# ngalor : ngalor
# ngidul : ngidul
# cocok : cocok
# klik : klik
# personal : personal
# tolak : tolak
# gugatan : gugat
# ketua : ketua
# dogiyai : dogiyai
# rekrutmen : rekrutmen
# anggota : anggota
# kpud : kpud
# kejutan : kejut
# besok : besok
# mayoritas : mayoritas
# pemilih : pilih
# prabowoganjar : prabowoganjar
# jalan : jalan
# beliau : beliau
# beli : beli
# takoyaki : takoyaki
# panggil : panggil
# pilkada : pilkada
# dimajukan : maju
# merusak : rusak
# rencana : rencana
# majukan : maju
# perppu : perppu
# sentil : sentil
# usia : usia
# diputus : putus
# anggaran : anggar
# pengusaha : usaha
# cawecawe : cawecawe
# subianto : subianto
# anggap : anggap
# urgensi : urgensi
# terbitkan : terbit
# mengaku : aku
# dpp : dpp
# sore : sore
# janjikan : janji
# dengar : dengar
# membelot : belot
# aniesnasdem : aniesnasdem
# dikhianati : khianat
# pinang : pinang
# nasdempkb : nasdempkb
# sepakat : sepakat
# kerja : kerja
# pendamping : damping
# rawan : rawan
# negeri : negeri
# maharani : maharani
# sambangi : sambang
# kuda : kuda
# cokelat : cokelat
# kediaman : diam
# ibunda : ibunda
# jombang : jombang
# doa : doa
# senyum : senyum
# khianati : khianat
# perubahan : ubah
# ahyanies : ahyanies
# diturunkan : turun
# surabaya : surabaya
# pasang : pasang
# ragukan : ragu
# pks : pks
# rumor : rumor
# tentukan : tentu
# sikap : sikap
# dikabarkan : kabar
# geram : geram
# husnuzan : husnuzan
# turunkan : turun
# ahy : ahy
# malam : malam
# kaget : kaget
# aniescak : aniescak
# duet : duet
# elite : elite
# dirangkul : rangkul
# damai : damai
# diisukan : isu
# tegaskan : tegas
# taat : taat
# aturan : atur
# kamar : kamar
# kelahiran : lahir
# gus : gus
# dur : dur
# beda : beda
# mejeng : mejeng
# jubir : jubir
# bakat : bakat
# pengkhianat : khianat
# cianjur : cianjur
# copot : copot
# campur : campur
# keretakan : kereta
# pengusung : usung
# surat : surat
# tulis : tulis
# tangan : tangan
# hengkang : hengkang
# bicarakan : bicara
# baikbaik : baikbaik
# sepucuk : pucuk
# poinpoin : poinpoin
# jumpa : jumpa
# salah : salah
# alamat : alamat
# gugat : gugat
# batas : batas
# caprescawapres : caprescawapres
# muhaimin : muhaimin
# dampingi : damping
# orang : orang
# ungkit : ungkit
# guru : guru
# spiritual : spiritual
# bisiki : bisik
# geger : geger
# isu : isu
# ppp : ppp
# demokratpks : demokratpks
# masuk : masuk
# diatur : atur
# paslon : paslon
# ingatkan : ingat
# era : era
# alasan : alas
# arti : arti
# lukisan : lukis
# no : no
# justice : justice
# peace : peace
# bentrok : bentrok
# kepentingan : penting
# larangan : larang
# berpasangan : pasang
# otomatis : otomatis
# pamit : pamit
# jejak : jejak
# pingit : pingit
# tandatanda : tandatanda
# bergejolak : gejolak
# kamis : kamis
# pleno : pleno
# sambut : sambut
# tawaran : tawar
# sejateng : sejateng
# copoti : copot
# gambar : gambar
# kiamat : kiamat
# sekjen : sekjen
# bertemu : temu
# emosional : emosional
# makna : makna
# seekor : ekor
# pimpin : pimpin
# merapat : rapat
# garuda : garuda
# menunggu : tunggu
# sragen : sragen
# bakar : bakar
# bergambar : gambar
# cabut : cabut
# diperingatkan : ingat
# kepercayaan : percaya
# potensi : potensi
# mengekor : ekor
# kemanapun : mana
# melangkah : lang
# lewati : lewat
# kepatutan : patut
# moral : moral
# etika : etika
# komunikasi : komunikasi
# percaya : percaya
# menyangka : sangka
# berkhianat : khianat
# jujur : jujur
# amanah : amanah
# batal : batal
# komentari : komentar
# belok : belok
# sein : sein
# lobi : lobi
# bentuk : bentuk
# setuju : tuju
# bongkar : bongkar
# reaksi : reaksi
# polisi : polisi
# info : info
# acara : acara
# manuver : manuver
# ketebak : tebak
# spontan : spontan
# keberatan : berat
# program : program
# akhirakhir : akhirakhir
# sarat : sarat
# aroma : aroma
# pengkhianatan : khianat
# pasangan : pasang
# dihadiri : hadir
# sekutu : sekutu
# kisruh : kisruh
# berujung : ujung
# pergi : pergi
# gabungdemokrat : gabungdemokrat
# lengkap : lengkap
# seberang : seberang
# lokasi : lokasi
# yahya : yahya
# nu : nu
# rebutan : rebut
# kebo : kebo
# aniespaloh : aniespaloh
# salim : salim
# segaf : segaf
# ikhlas : ikhlas
# dighosting : dighosting
# maaf : maaf
# hormati : hormat
# hotel : hotel
# majapahit : majapahit
# jomblo : jomblo
# ganggu : ganggu
# pbnu : pbnu
# panggung : panggung
# bacapres : bacapres
# munas : munas
# konbes : konbes
# berpeluang : peluang
# impor : impor
# energi : energi
# menang : menang
# ummat : ummat
# beberkan : kan
# alasanalasan : alasanalasan
# pekik : pekik
# merdeka : merdeka
# pindah : pindah
# gerbong : gerbong
# upaya : upaya
# jegal : jegal
# hukum : hukum
# ihza : ihza
# mahendra : mahendra
# alternatif : alternatif
# kutip : kutip
# ucapan : ucap
# kumpul : kumpul
# otorita : otorita
# pembangunan : bangun
# ikn : ikn
# terganggu : ganggu
# pergantian : ganti
# pakar : pakar
# kemas : kemas
# ulang : ulang
# narasi : narasi
# intensif : intensif
# tinggalkan : tinggal
# ribuan : ribu
# bosan : bosan
# zikir : zikir
# ucapkan : ucap
# pbb : pbb
# didorong : dorong
# putri : putri
# gusdurian : gusdurian
# organisasi : organisasi
# terganjal : ganjal
# hubungan : hubung
# sbymega : sbymega
# condong : condong
# bareskrim : bareskrim
# wajibkan : wajib
# peserta : serta
# pemilupilpres : pemilupilpres
# bangun : bangun
# budaya : budaya
# bermartabat : martabat
# terbuka : buka
# perhitungkan : hitung
# usul : usul
# lantunkan : lantun
# bento : bento
# pengamen : amen
# jalanan : jalan
# lengser : lengser
# wagub : wagub
# sumut : sumut
# ijeck : ijeck
# fokus : fokus
# klaim : klaim
# psi : psi
# wa : wa
# agree : agree
# disagree : disagree
# dipaksa : paksa
# nyatakan : nyata
# move : move
# on : on
# ja : ja
# favorit : favorit
# ketiga : tiga
# maafkan : maaf
# sakiti : sakit
# sukses : sukses
# sahroni : sahroni
# kecewa : kecewa
# kepedean : kepedean
# pemimpin : pimpin
# pemersatu : satu
# umat : umat
# sesuai : sesuai
# kriteria : kriteria
# menaq : menaq
# yaqut : yaqut
# setia : setia
# pagi : pagi
# tempe : tempe
# rp : rp
# gaji : gaji
# pegawai : pegawai
# perjuangan : juang
# dilukai : luka
# pamitan : pamit
# seruuu : seruuu
# banget : banget
# ngobrolnya : ngobrolnya
# insya : insya
# allah : allah
# songsong : songsong
# perjalanan : jalan
# penentuan : tentu
# hitungan : hitung
# menit : menit
# ketimbang : ketimbang
# aktivis : aktivis
# bukabukaan : bukabukaan
# jabatan : jabat
# koster : koster
# istirahat : istirahat
# tancap : tancap
# gas : gas
# urus : urus
# ambigu : ambigu
# beban : beban
# publik : publik
# rancangan : rancang
# pkpu : pkpu
# grace : grace
# drama : drama
# sinetron : sinetron
# profil : profil
# arsjad : arsjad
# rasjid : rasjid
# peluang : peluang
# pertemukan : temu
# aset : aset
# harap : harap
# cari : cari
# draf : draf
# pendaftaran : daftar
# oktober : oktober
# andika : andika
# perkasa : perkasa
# diberitahu : diberitahu
# wakil : wakil
# direstui : restu
# kiai : kiai
# khos : khos
# purworejo : purworejo
# puncak : puncak
# perbedaan : beda
# buntu : buntu
# gebrak : gebrak
# meja : meja
# panas : panas
# curiga : curiga
# intervensi : intervensi
# jadwal : jadwal
# ancam : ancam
# sanksi : sanksi
# pengurus : urus
# bawabawa : bawabawa
# tpn : tpn
# paham : paham
# radar : radar
# sulit : sulit
# yenny : yenny
# wasiat : wasiat
# wafat : wafat
# diganti : ganti
# masyumi : masyumi
# tower : tower
# diulangi : ulang
# wahid : wahid
# dikudeta : kudeta
# temanteman : temanteman
# menerus : terus
# blakblakan : blakblakan
# intrik : intrik
# kudeta : kudeta
# benny : benny
# harman : harman
# jahat : jahat
# breaking : breaking
# mohon : mohon
# maklum : maklum
# siang : siang
# rancang : rancang
# dinamis : dinamis
# panggilan : panggil
# kpk : kpk
# murni : murni
# mtq : mtq
# duga : duga
# intimidasi : intimidasi
# opsi : opsi
# berhak : hak
# larang : larang
# warganya : warga
# ngaku : ngaku
# jeda : jeda
# tugas : tugas
# jawa : jawa
# barat : barat
# tito : tito
# dipercepat : cepat
# dudung : dudung
# purnawirawan : purnawirawan
# pengaruhi : pengaruh
# prajurit : prajurit
# aktif : aktif
# imbauan : imbau
# menag : menag
# mas : mas
# persis : persis
# kertanegara : kertanegara
# prabowoyenny : prabowoyenny
# balas : balas
# hormat : hormat
# disambut : sambut
# komisioner : komisioner
# laporan : lapor
# dkpp : dkpp
# tahapan : tahap
# kronologi : kronologi
# ditolak : tolak
# marah : marah
# kumpulkan : kumpul
# dpd : dpd
# seindonesia : indonesia
# arah : arah
# rebut : rebut
# hati : hati
# selawat : selawat
# kantor : kantor
# tahap : tahap
# disahkan : sah
# clbk : clbk
# kehormatan : hormat
# bersuara : suara
# political : political
# road : road
# show : show
# part : part
# staquf : staquf
# lahir : lahir
# sepakati : sepakat
# identitas : identitas
# optimis : optimis
# diterima : terima
# majelis : majelis
# syuro : syuro
# restu : restu
# jatim : jatim
# pmii : pmii
# hashim : hashim
# gratis : gratis
# butuh : butuh
# kyai : kyai
# simpati : simpati
# kasad : kasad
# kode : kode
# mukjizat : mukjizat
# kompas : kompas
# pdipganjar : pdipganjar
# gerindraprabowo : gerindraprabowo
# minggu : minggu
# as : as
# soroti : sorot
# khofifah : khofifah
# ajukan : aju
# diperiksa : periksa
# andi : andi
# arief : arief
# usulkan : usul
# timses : timses
# sing : sing
# sabar : sabar
# buton : buton
# kondisi : kondisi
# mabuk : mabuk
# figur : figur
# aniesmuhaimin : aniesmuhaimin
# strategis : strategis
# wujudkan : wujud
# tipis : tipis
# kans : kans
# mundur : mundur
# ambisi : ambisi
# pertimbangan : timbang
# berharap : harap
# pilar : pilar
# utama : utama
# persatuan : satu
# kuat : kuat
# megawatisby : megawatisby
# barikade : barikade
# tinggal : tinggal
# pengemudi : kemudi
# ojol : ojol
# pastikan : pasti
# bersedia : sedia
# aqil : aqil
# heran : heran
# periksa : periksa
# kemarinkemarin : kemarinkemarin
# ketuk : ketuk
# teuku : teuku
# umar : umar
# ulama : ulama
# kharismatik : kharismatik
# kh : kh
# thoifur : thoifur
# kubu : kubu
# mempersatukan : satu
# kehadiran : hadir
# mahfud : mahfud
# md : md
# bertengkar : tengkar
# safari : safari
# tuding : tuding
# lemah : lemah
# bapaknya : bapak
# kena : kena
# ghosting : ghosting
# hasto : hasto
# berpolitik : politik
# praktis : praktis
# berat : berat
# peta : peta
# pemilik : milik
# mendagri : mendagri
# percepatan : cepat
# berisiko : risiko
# muncul : muncul
# tayangan : tayang
# azan : azan
# tv : tv
# perindo : perindo
# seruan : seru
# kebaikan : baik
# sandiaga : sandiaga
# uno : uno
# utusan : utus
# berpotensi : potensi
# ditugasi : tugas
# miftah : miftah
# lagu : lagu
# capresku : capresku
# jadwalkan : jadwal
# maman : maman
# pembaruan : baru
# berkelanjutan : lanjut
# niat : niat
# enggan : enggan
# komentar : komentar
# kpi : kpi
# polling : polling
# institute : institute
# terkuat : kuat
# tokoh : tokoh
# bamsoet : bamsoet
# terjebak : jebak
# transaksional : transaksional
# nomor : nomor
# piro : piro
# wani : wani
# ngopi : ngopi
# unggul : unggul
# syaratkan : syarat
# surati : surati
# stasiun : stasiun
# klarifikasi : klarifikasi
# sosok : sosok
# penggebrak : gebrak
# alot : alot
# jatah : jatah
# cair : cair
# sebaran : sebar
# pulau : pulau
# sumatera : sumatera
# dana : dana
# desa : desa
# miliar : miliar
# hidayat : hidayat
# nur : nur
# akur : akur
# lancar : lancar
# menguat : kuat
# arsul : arsul
# candaan : canda
# berubah : ubah
# kunjungan : kunjung
# perdana : perdana
# sowan : sowan
# didoakan : doa
# wapres : wapres
# siratkan : sirat
# timur : timur
# naikkan : naik
# usulan : usul
# dibahas : bahas
# ujugujug : ujugujug
# fahri : fahri
# hamzah : hamzah
# menindak : tindak
# bebas : bebas
# dagang : dagang
# sapi : sapi
# maruf : maruf
# amin : amin
# media : media
# penyiaran : siar
# santai : santai
# posisi : posisi
# hasilnya : hasil
# komisi : komisi
# ii : ii
# peremajaan : remaja
# videojokowi : videojokowi
# nyapres : nyapres
# fasilitas : fasilitas
# tsamara : tsamara
# amany : amany
# saksi : saksi
# agum : agum
# gumelar : gumelar
# pepabri : pepabri
# netral : netral
# semut : semut
# merah : merah
# berlari : lari
# jas : jas
# biru : biru
# duduk : duduk
# bersebelahan : bahan
# nyanyi : nyanyi
# kspsi : kspsi
# megasby : megasby
# bola : bola
# panda : panda
# utang : utang
# diberesin : resin
# diungkit : ungkit
# nababan : nababan
# libur : libur
# pencoblosan : coblos
# sukmawati : sukmawati
# bagus : bagus
# absen : absen
# titip : titip
# pesan : pesan
# ahmad : ahmad
# syaikhu : syaikhu
# ciptaan : cipta
# agama : agama
# bela : bela
# kuncinya : kunci
# bandingkan : banding
# rempang : rempang
# kampung : kampung
# akuarium : akuarium
# luka : luka
# mendalam : dalam
# peran : peran
# gocapan : gocap
# uang : uang
# sedekah : sedekah
# sbyprabowo : sbyprabowo
# karaoke : karaoke
# mufakat : mufakat
# bagibagi : bagibagi
# waketum : waketum
# panglima : panglima
# atribut : atribut
# tni : tni
# mengerucut : kerucut
# dibicarakan : bicara
# tempel : tempel
# stiker : stiker
# maluku : malu
# wajar : wajar
# dikerjai : kerja
# menjanjikan : janji
# menhan : menhan
# bagja : bagja
# terlibat : libat
# kkb : kkb
# lanjutkan : lanjut
# misi : misi
# habibie : habibie
# pesawat : pesawat
# santri : santri
# tiktok : tiktok
# langgar : langgar
# dijatuhi : jatuh
# peringatan : ingat
# sediakan : sedia
# rilis : rilis
# bacawapres : bacawapres
# tgb : tgb
# konflik : konflik
# pengakuan : aku
# diundang : undang
# berebut : rebut
# kesempatan : sempat
# menpan : menpan
# rb : rb
# jaga : jaga
# netralitas : netralitas
# asn : asn
# kemendagri : kemendagri
# tanggal : tanggal
# setujui : tuju
# bahaya : bahaya
# timnas : timnas
# wakapolri : wakapolri
# petunjuk : tunjuk
# wo : wo
# canda : canda
# bidah : bidah
# ambil : ambil
# keputusan : putus
# rekam : rekam
# jaksa : jaksa
# agung : agung
# prasetyo : prasetyo
# dewan : dewan
# pengarah : arah
# semalam : malam
# dikawal : kawal
# jenderal : jenderal
# pensiunan : pensiun
# tnipolri : tnipolri
# perkuat : kuat
# jabar : jabar
# khawatir : khawatir
# radikalisme : radikalisme
# dianggap : anggap
# ikatan : ikat
# lengkapi : lengkap
# struktur : struktur
# menyusul : susul
# tegur : tegur
# ganjarridwan : ganjarridwan
# menguntungkan : untung
# dilibatkan : libat
# berencana : rencana
# avengers : avengers
# geleng : geleng
# guyon : guyon
# adu : adu
# versi : versi
# amien : amien
# rais : rais
# sumbar : sumbar
# sosialisasi : sosialisasi
# parlemen : parlemen
# buruh : buruh
# hapus : hapus
# presidential : presidential
# threshold : threshold
# magrib : magrib
# videonya : video
# viral : viral
# zulkifli : zulkifli
# hasan : hasan
# prabowork : prabowork
# urusan : urus
# golkarpan : golkarpan
# terendah : rendah
# smrc : smrc
# dki : dki
# rendah : rendah
# aniesimin : aniesimin
# keempat : empat
# dinilai : nilai
# diklaim : klaim
# menikmati : nikmat
# underdog : underdog
# ppatk : ppatk
# berambisi : ambisi
# kekuatan : kuat
# kejahatan : jahat
# guyonan : guyon
# terbaru : baru
# syarat : syarat
# apapun : apa
# dibolehkan : boleh
# lempar : lempar
# dipimpin : pimpin
# lakilaki : lakilaki
# tampan : tampan
# fisip : fisip
# diusung : usung
# optimistis : optimistis
# raih : raih
# juta : juta
# basis : basis
# jabarjakarta : jabarjakarta
# paparkan : papar
# dalih : dalih
# sahabat : sahabat
# pria : pria
# jeroan : jeroan
# berkat : berkat
# bin : bin
# bais : bais
# relakan : rela
# madrasah : madrasah
# penyuluh : suluh
# dipakai : pakai
# tugaskan : tugas
# tarung : tarung
# hambalang : hambalang
# mari : mari
# jemput : jemput
# gunung : gunung
# plus : plus
# minus : minus
# agamawan : agamawan
# wiranto : wiranto
# gagas : gagas
# kenaikan : naik
# bumn : bumn
# gemuk : gemuk
# jamin : jamin
# munaskonbes : munaskonbes
# informasi : informasi
# intelijen : intelijen
# dimiliki : milik
# rapimnas : rapimnas
# diputuskan : putus
# artis : artis
# bertarung : tarung
# uya : uya
# kuya : kuya
# pasha : pasha
# ungu : ungu
# tertutup : tutup
# menyumbang : sumbang
# dibatasi : batas
# kahmi : kahmi
# gagasan : gagas
# effendy : effendy
# najwa : najwa
# shihab : shihab
# menyeberang : seberang
# petugas : tugas
# lihat : lihat
# layanan : layan
# ai : ai
# kayak : kayak
# jazilul : jazilul
# boneka : boneka
# pertimbangkan : timbang
# jabat : jabat
# berjodoh : jodoh
# perjuangkan : juang
# perbaikan : baik
# tka : tka
# china : china
# infografis : infografis
# tpsmobilisasi : tpsmobilisasi
# kapolri : kapolri
# undangan : undang
# investasi : investasi
# rugikan : rugi
# masyarakat : masyarakat
# hinca : hinca
# sbymegawati : sbymegawati
# akun : akun
# kebun : kebun
# binatang : binatang
# diretas : retas
# posting : posting
# ugm : ugm
# kim : kim
# dijadwalkan : jadwal
# agraria : agraria
# tercatat : catat
# penyalahgunaan : penyalahgunaan
# sarapan : sarap
# anggapan : anggap
# kemiskinan : miskin
# ekstrem : ekstrem
# mesti : mesti
# nol : nol
# turis : turis
# bali : bal
# kontribusi : kontribusi
# masukkan : masuk
# byebye : byebye
# kualitas : kualitas
# sdm : sdm
# gantikan : ganti
# ig : ig
# promosikan : promosi
# mnc : mnc
# kelakar : kelakar
# sri : sri
# mulyani : mulyani
# banggar : banggar
# koleksi : koleksi
# kendaraan : kendara
# siaran : siar
# populer : populer
# ormas : ormas
# islam : islam
# rekomendasi : rekomendasi
# muhammadiyah : muhammadiyah
# projo : projo
# rahasia : rahasia
# dicoret : coret
# ribu : ribu
# suka : suka
# cekik : cekik
# wamen : wamen
# ngerti : ngerti
# fitnah : fitnah
# kerap : kerap
# diejek : ejek
# pusing : pusing
# urut : urut
# terpengaru : aru
# alifurrahman : alifurrahman
# sebar : sebar
# cekiktampar : cekiktampar
# jual : jual
# biayai : biaya
# permintaan : minta
# tempuh : tempuh
# tom : tom
# lembong : lembong
# reindustrialisasi : reindustrialisasi
# padat : padat
# karya : karya
# kurangi : kurang
# pengangguran : anggur
# cetak : cetak
# kaesang : kaesang
# persiapan : siap
# curhat : curhat
# ngaji : ngaji
# sediy : sediy
# kesal : kesal
# difitnah : fitnah
# ganti : ganti
# visi : visi
# ragu : ragu
# didaftarkan : daftar
# bantahan : bantah
# kemenkeu : kemenkeu
# catut : catut
# timbulkan : timbul
# keresahan : resah
# deadlock : deadlock
# afgan : afgan
# terapkan : terap
# hitung : hitung
# panel : panel
# percepat : cepat
# diwarnai : warna
# perdebatan : debat
# jcc : jcc
# senayan : senayan
# rudi : rudi
# kamri : kamri
# pendidikan : didik
# gizi : gizi
# depresi : depresi
# kepikiran : pikir
# situ : situ
# susah : susah
# terwujud : wujud
# darurat : darurat
# cipta : cipta
# kalkulasi : kalkulasi
# kominfo : kominfo
# hoaks : hoaks
# takedown : takedown
# solo : solo
# wajah : wajah
# bro : bro
# sutiyoso : sutiyoso
# konsisten : konsisten
# berani : berani
# kukuh : kukuh
# peneliti : teliti
# brin : brin
# terindikasi : indikasi
# peluk : peluk
# last : last
# minute : mute
# barus : barus
# cenderung : cenderung
# benarkan : benar
# disepakati : pakat
# titipan : titip
# natalie : natalie
# kta : kta
# ganjarprabowo : ganjarprabowo
# mengubah : ubah
# ekonomi : ekonomi
# absolut : absolut
# joget : joget
# harapan : harap
# videokaesang : videokaesang
# djarot : djarot
# keluarga : keluarga
# baja : baja
# berisi : isi
# pelukis : peluk
# musyawarah : musyawarah
# analisis : analisis
# medsos : medsos
# drone : drone
# emprit : emprit
# buruk : buruk
# bangsa : bangsa
# persen : persen
# menyongsong : songsong
# sadar : sadar
# superman : superman
# supertim : supertim
# 0      [dpo, ppln, kuala, lumpur, serah, langsung, si...
# 1      [amat, nilai, prabowogibran, kunci, demokrasi,...
# 2      [hasil, rekapitulasi, provinsi, prabowogibran,...
# 3      [dpr, undang, kpu, rapat, evaluasi, milu, reka...
# 4          [kris, dayanti, aku, gagal, lolos, dpr, milu]
#                              ...
# 694       [video, puji, ahy, prabowo, ahy, aset, bangsa]
# 695    [jokowi, klaim, bangun, kantor, presiden, ikn,...
# 696              [anies, isu, capres, songsong, pilpres]
# 697    [video, ahy, prabowo, sadar, superman, butuh, ...
# 698    [aniescak, imin, bentuk, baja, amin, ganti, ti...
# Name: news-tokens-stemmed, Length: 699, dtype: object

# %% [markdown]
# ## Save data

# %%
pemilu_data_new = pemilu_data.drop(columns=['web-scraper-order','web-scraper-start-url', 'pages'])

print(pemilu_data.columns)

print(pemilu_data_new.columns)
# Out:
# Index(['web-scraper-order', 'web-scraper-start-url', 'news-title', 'pages',
#        'news-tokens', 'news-tokens-fdist', 'news-tokens-wsw',
#        'news-normalized', 'news-tokens-stemmed'],
#       dtype='object')
# Index(['news-title', 'news-tokens', 'news-tokens-fdist', 'news-tokens-wsw',
#        'news-normalized', 'news-tokens-stemmed'],
#       dtype='object')

# %%
# Save to excel

pemilu_data_new.to_excel("results/Pemilu_Text_Preprocessing.xlsx")

# %%
# Save to csv

pemilu_data_new.to_csv("results/Pemilu_Test_Preprocessing.csv")
